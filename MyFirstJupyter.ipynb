# %% [markdown]
# #  Заголовок1

# %% [markdown]
# ### Заголовок 2 уровня

# %%
print('hello!')
# Out:
# hello!

# %% [markdown]
# $$c= \sqrt(a^2 + b^2)$$

# %%
# %matplotlib inline

# %%
plot([1, 4, 5, 6])
